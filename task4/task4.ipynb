# %% [markdown]
# # Part 1

# %%
# Get input
with open('input.txt', 'r') as f:
    inp = f.read()

# %%
[i.split(',') for i in inp.split('\n')]
# Out:
# [['82-82', '8-83'],
#  ['6-98', '6-93'],
#  ['56-77', '55-82'],
#  ['51-68', '51-61'],
#  ['4-90', '3-67'],
#  ['29-30', '29-97'],
#  ['42-88', '13-87'],
#  ['17-95', '33-96'],
#  ['11-56', '12-56'],
#  ['16-90', '89-94'],
#  ['74-79', '78-80'],
#  ['20-82', '19-87'],
#  ['4-86', '5-85'],
#  ['37-54', '37-55'],
#  ['15-92', '16-91'],
#  ['48-93', '3-92'],
#  ['23-47', '7-47'],
#  ['75-77', '2-76'],
#  ['35-88', '35-87'],
#  ['56-64', '65-89'],
#  ['17-80', '18-79'],
#  ['28-87', '27-88'],
#  ['6-62', '61-63'],
#  ['25-85', '24-25'],
#  ['10-72', '12-72'],
#  ['54-71', '44-70'],
#  ['20-96', '97-99'],
#  ['19-46', '14-47'],
#  ['7-97', '3-6'],
#  ['14-78', '5-7'],
#  ['98-98', '40-98'],
#  ['1-92', '1-83'],
#  ['14-52', '13-68'],
#  ['40-43', '40-82'],
#  ['13-96', '95-98'],
#  ['16-18', '17-82'],
#  ['69-79', '3-70'],
#  ['24-58', '23-25'],
#  ['96-96', '2-96'],
#  ['5-99', '4-97'],
#  ['7-11', '12-95'],
#  ['26-28', '1-27'],
#  ['4-35', '2-7'],
#  ['22-94', '21-95'],
# ...
